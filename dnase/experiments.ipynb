# %%
# !ls
# Out:
# experiments.ipynb	 mixed_valid_outputs.npy  train_targets.npy
# linear.py		 mixed_valid_targets.npy  Untitled1.ipynb
# load_data.py		 __pycache__		  Untitled.ipynb
# make_data.py		 test_logits.npy	  valid_logits.npy
# mixed_test_outputs.npy	 test_outputs.npy	  valid_outputs.npy
# mixed_test_targets.npy	 test_targets.npy	  valid_targets.npy
# mixed_train_outputs.npy  train_logits.npy
# mixed_train_targets.npy  train_outputs.npy

# %%
import collections

import numpy as np
import sklearn.linear_model as lm
import sklearn.metrics
import matplotlib.pyplot as plt
import tensorflow as tf
# %matplotlib inline

# %% [markdown]
# # Data Prep

# %%
train_data = {
    "deepsea_outputs": np.load("mixed_train_outputs.npy"),
#     "deepsea_logits": np.load("mixed_train_logits.npy"),
    "y": np.load("mixed_train_targets.npy")
}

valid_data = {
    "deepsea_outputs": np.load("mixed_valid_outputs.npy"),
#     "deepsea_logits": np.load("mixed_valid_logits.npy"),
    "y": np.load("mixed_valid_targets.npy")
}

test_data = {
    "deepsea_outputs": np.load("mixed_test_outputs.npy"),
#     "deepsea_logits": np.load("mixed_test_logits.npy"),
    "y": np.load("mixed_test_targets.npy")
}

# The validation set isn't big enough, so we take some from the training data.

# valid_data = {
#     "deepsea_outputs": np.concatenate([train_data["deepsea_outputs"][2200000:2400000],train_data["deepsea_outputs"][4200000:4400000],valid_data["deepsea_outputs"]], axis=0),
#     "deepsea_logits": np.concatenate([train_data["deepsea_logits"][2200000:2400000],train_data["deepsea_logits"][4200000:4400000],valid_data["deepsea_logits"]], axis=0),
#     "y": np.concatenate([train_data["y"][2200000:2400000],train_data["y"][4200000:4400000],valid_data["y"]], axis=0),
# }

# train_data = {
#     "deepsea_outputs": np.concatenate([train_data["deepsea_outputs"][0:2200000],train_data["deepsea_outputs"][2400000:4200000]], axis=0),
#     "deepsea_logits": np.concatenate([train_data["deepsea_logits"][0:2200000],train_data["deepsea_logits"][2400000:4200000]], axis=0),
#     "y": np.concatenate([train_data["y"][0:2200000],train_data["y"][2400000:4200000]], axis=0),
# }

# %%
def auc(data, i):
    preds = data["deepsea_outputs"][:,i]
    labels = data["y"][:,i]
    return sklearn.metrics.roc_auc_score(labels, preds), sklearn.metrics.average_precision_score(labels, preds)

for i in range(19):
    print(auc(test_data, i))
# Out:
# (0.8576999749578289, 0.3700919542349726)
# (0.949170615226667, 0.23610223599386693)
# (0.9190826378212813, 0.20606869476955997)
# (0.975220128673865, 0.3421692799670427)
# (0.9682384003175021, 0.26922895046567935)
# (0.9408194690857059, 0.21734958916440345)
# (0.8829324011424516, 0.09433629608663682)
# (0.8525510340702873, 0.10240875075834234)
# (0.9357889649853666, 0.16207282134671605)
# (0.9195035610423528, 0.257718006823373)
# (0.9908787776505924, 0.37266025339094444)
# (0.9380315134763743, 0.4277794118709136)
# (0.743376195709318, 0.03619128545701074)
# (0.9697098562189721, 0.5690863763254849)
# (0.9475160166501252, 0.4793680352387042)
# (0.9046498023337772, 0.3141778089793572)
# (0.968621516482024, 0.28637023371384657)
# (0.6814545708858999, 0.002103403845389069)
# (0.7081355091960853, 0.0200487974038576)

# %%
def make_dataset(data,
                 batch_size,
                 shuffle_size,
                 prefetch_size,
                 generator_fn):
    
    x_shape, gen = generator_fn(data)
    
    dataset = tf.data.Dataset.from_generator(
        gen,
        output_types=(tf.float32,)*3,
        output_shapes=(data["y"].shape[1], x_shape, data["y"].shape[1],)
    )
    dataset = dataset.batch(batch_size)
    dataset = dataset.shuffle(shuffle_size)
    dataset = dataset.repeat()
    dataset = dataset.prefetch(prefetch_size)
    return dataset.make_one_shot_iterator()

# Generators output (DeepSea's probs, model inputs, ground truth)

def identity_gen(data):
    def g():
        for probs, logits, y in zip(data["deepsea_outputs"], data["deepsea_logits"], data["y"]):
            yield probs, logits, y
    return data["deepsea_logits"].shape[1], g

def random_mask(p, shape):
    return lambda: np.random.binomial(1, p, shape)

def dnase_mask():
    return np.array([1] + 18 * [0])

def position_mask(ids):
    out = np.zeros(19)
    out[ids] = 1
    return lambda: out

def imputation_gen(data, mask_fn=random_mask(.1, 19), x_shape=19*3):
    def g():
        for probs, logits, y in zip(data["deepsea_outputs"], data["deepsea_logits"], data["y"]):
            mask = mask_fn()
            x = y * mask + probs * (1 - mask)
            x = np.concatenate([logits, x, mask], axis=0)
            yield probs, x, y
    return x_shape, g
            
def paramaterized_imputation_gen(mask_fn, x_shape):
    return lambda data: imputation_gen(data, mask_fn, x_shape)

# %% [markdown]
# # Model definition

# %%
class Model():
    def __init__(self,
                 train_data,
                 valid_data,
                 num_outputs,
                 batch_size=64,
                 shuffle_size=10000,
                 prefetch_size=10,
                 l1=0.,
                 l2=0.,
                 lr=1e-3,
                 generator_fn=identity_gen,
                 masking=True):
        
        self.graph = tf.Graph()

        with self.graph.as_default() as graph:
            tf.logging.set_verbosity(tf.logging.INFO)


            train_iter = make_dataset(train_data, batch_size, shuffle_size, prefetch_size, generator_fn)
            valid_iter = make_dataset(valid_data, batch_size, 1           , prefetch_size, generator_fn)
            self.train_handle = train_iter.string_handle()
            self.valid_handle = valid_iter.string_handle()
            self.handle = tf.placeholder(tf.string, shape=[])
            iterator = tf.data.Iterator.from_string_handle(
                self.handle, train_iter.output_types, train_iter.output_shapes)
            self.deepsea_pred, self.x, self.y = iterator.get_next()
            
            self.sess = tf.InteractiveSession(graph=graph)

            self.num_outputs = num_outputs
            self.l1, self.l2 = l1, l2
            self.default_lr = lr
            self.lr = tf.placeholder(tf.float32)
            self.batch_size = batch_size
            self.prefetch_size = prefetch_size
            self.masking = masking

            self.global_step = tf.Variable(0, name='global_step', trainable=False)
            self.logits = self.body_fn()
            self.predictions = tf.sigmoid(self.logits)
            self.loss = self.loss_fn()
            self.min = self.minimizer_fn()
        
    def make_alt_dataset(self, data, batch_size, shuffle_size, prefetch_size, generator_fn):
        with self.graph.as_default():
            h = make_dataset(data, batch_size, shuffle_size, prefetch_size, generator_fn).string_handle()
            return self.sess.run(h)
                
    def body_fn(self):
        raise NotImplementedError()
    
    def loss_fn(self):
        return tf.reduce_mean(tf.nn.weighted_cross_entropy_with_logits(self.y, self.logits, 50))
    
    def minimizer_fn(self):
        self.opt = tf.train.AdamOptimizer(self.lr)
        return self.opt.minimize(self.loss, self.global_step)
        
    def train(self, num_steps, lr=None):
        with self.graph.as_default():
            if lr == None:
                lr = self.default_lr
            try:
                self.sess.run(self.global_step)
            except:
                tf.logging.info("Initializing variables")
                self.sess.run(tf.global_variables_initializer())
                self.train_handle = self.sess.run(self.train_handle)
                self.valid_handle = self.sess.run(self.valid_handle)

            max_steps = self.sess.run(self.global_step) + num_steps

            tf.logging.info("Starting Training")

            while self.sess.run(self.global_step) < max_steps:
                _, loss = self.sess.run([self.min, self.loss], {self.handle: self.train_handle, self.lr: lr})
                step = self.sess.run(self.global_step)
                if step % 1000 == 0:
                    tf.logging.info(str(step) + " " + str(loss))
                    tf.logging.info("On validation")
                    _, _, _, stop = self.test(8000, log=True, masking=self.masking)
                    if stop: break
                    tf.logging.info("")
                
    def test(self, num_samples, log=False, iterator_handle=None, masking=True):
        with self.graph.as_default():
            vals = []
            for i in range(int(num_samples / self.batch_size)):
                vals.append(
                    self.sess.run([self.deepsea_pred, self.predictions, self.x, self.y],
                             {self.handle: iterator_handle if iterator_handle else self.valid_handle})
                )
            deepsea = np.concatenate([v[0] for v in vals])
            preds = np.concatenate([v[1] for v in vals])
            truth = np.concatenate([v[3] for v in vals])
            if log and masking:
                mask = 1 - np.concatenate([v[2][:,19*2:] for v in vals]).reshape((-1))

                our_score = sklearn.metrics.roc_auc_score(truth.reshape((-1)), preds.reshape((-1)),   sample_weight=mask)
                deepsea_score = sklearn.metrics.roc_auc_score(truth.reshape((-1)), deepsea.reshape((-1)), sample_weight=mask)

                # Masked micro average
                tf.logging.info("Our AUC:     " + str(our_score))
                tf.logging.info("DeepSea AUC: " + str(deepsea_score))

#                 return deepsea, preds, truth, our_score > deepsea_score

            return deepsea, preds, truth, False

# %%
class Logistic(Model):
    def body_fn(self):
        return tf.layers.dense(self.x, self.num_outputs, kernel_regularizer=tf.contrib.layers.l1_l2_regularizer(self.l1, self.l2))
    
class MLP(Model):
    def __init__(self,
             layers,
             num_units,
             activation,
             *args,
             **kwargs):

        self.layers = layers
        self.num_units = num_units
        self.activation = activation
        
        Model.__init__(self, *args, **kwargs)
            
    def body_fn(self):
        model = self.x
        
        if not isinstance(self.num_units, collections.Iterable):
            self.num_units = [self.num_units] * self.layers
            
        for i in range(self.layers):
            model = tf.layers.dense(model, self.num_units[i], self.activation, kernel_regularizer=tf.contrib.layers.l1_l2_regularizer(self.l1, self.l2))
            
        return tf.layers.dense(model, self.num_outputs, kernel_regularizer=tf.contrib.layers.l1_l2_regularizer(self.l1, self.l2))

# %% [markdown]
# # Training

# %%
# try:
#     sess.close()
# except:
#     pass
# tf.reset_default_graph()
# sess = tf.InteractiveSession()

# %%
# logistic = Logistic(train_data, valid_data, 19, shuffle_size=1, generator_fn=imputation_fn)
# logistic.train(sess, 10000, lr=1e-4)
# imp8 = logistic.make_alt_dataset(sess, valid_data, 64, 1, 10, paramaterized_imputation_gen(random_mask(.8, 19), 3*19))
# dnase = logistic.make_alt_dataset(sess, valid_data, 64, 1, 10, paramaterized_imputation_gen(dnase_mask, 3*19))
# none = logistic.make_alt_dataset(sess, valid_data, 64, 1, 10, paramaterized_imputation_gen(random_mask(0, 19), 3*19))

# _ = logistic.test(sess, 40000, log=True)
# _ = logistic.test(sess, 40000, log=True, iterator_handle=imp8)
# _ = logistic.test(sess, 40000, log=True, iterator_handle=dnase)
# _ = logistic.test(sess, 40000, log=True, iterator_handle=none)

# %%
# mlp = MLP(2, 20, tf.tanh, train_data, valid_data, 19, shuffle_size=1, generator_fn=imputation_gen)
# mlp.train(sess, 20000, lr=1e-3)
# mlp.train(sess, 20000, lr=1e-4)
# mlp.train(sess, 20000, lr=1e-5)
# imp8 = mlp.make_alt_dataset(sess, valid_data, 64, 1, 10, paramaterized_imputation_gen(random_mask(.8, 19), 3*19))
# dnase = mlp.make_alt_dataset(sess, valid_data, 64, 1, 10, paramaterized_imputation_gen(dnase_mask, 3*19))
# _ = mlp.test(sess, 16000, log=True)
# for _ in range(3):
#     _ = mlp.test(sess, 16000, log=True, iterator_handle=imp8)

# %%
mlps = []
for i in range(3):
    mlp = MLP(4, 40, tf.tanh, train_data, valid_data, 19, shuffle_size=1, generator_fn=paramaterized_imputation_gen(position_mask([i]), 3*19), l1=.1)
    mlp.train(40000, lr=1e-3)
    mlp.train(40000, lr=1e-4)
    mlps.append(mlp)
# Out:
# /data/jwhughes/miniconda3/envs/tf_env/lib/python3.6/site-packages/tensorflow/python/client/session.py:1645: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '
# INFO:tensorflow:Initializing variables
# INFO:tensorflow:Starting Training
# INFO:tensorflow:1000 0.20888677
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9558741311842852
# INFO:tensorflow:DeepSea AUC: 0.9659993520392898
# INFO:tensorflow:
# INFO:tensorflow:2000 0.059482787
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9614680041206085
# INFO:tensorflow:DeepSea AUC: 0.9696383207749399
# INFO:tensorflow:
# INFO:tensorflow:3000 0.9156255
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9636511078557051
# INFO:tensorflow:DeepSea AUC: 0.9674656211640514
# INFO:tensorflow:
# INFO:tensorflow:4000 0.045395236
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.975934296714044
# INFO:tensorflow:DeepSea AUC: 0.9804013362687495
# INFO:tensorflow:
# INFO:tensorflow:5000 0.27990714
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9498826961194554
# INFO:tensorflow:DeepSea AUC: 0.9561572637079102
# INFO:tensorflow:
# INFO:tensorflow:6000 0.51744586
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9492783881903334
# INFO:tensorflow:DeepSea AUC: 0.9624254657226413
# INFO:tensorflow:
# INFO:tensorflow:7000 0.034468044
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9691240730106783
# INFO:tensorflow:DeepSea AUC: 0.9758324066546488
# INFO:tensorflow:
# INFO:tensorflow:8000 0.17269738
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9662339230155086
# INFO:tensorflow:DeepSea AUC: 0.9729545051535441
# INFO:tensorflow:
# INFO:tensorflow:9000 0.044648755
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.972743360574413
# INFO:tensorflow:DeepSea AUC: 0.9780647467508929
# INFO:tensorflow:
# INFO:tensorflow:10000 0.23308013
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9781820215636992
# INFO:tensorflow:DeepSea AUC: 0.9781379450916543
# INFO:tensorflow:
# INFO:tensorflow:11000 0.2969862
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9578395089019129
# INFO:tensorflow:DeepSea AUC: 0.9675698057878523
# INFO:tensorflow:
# INFO:tensorflow:12000 0.18783796
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9704157982528447
# INFO:tensorflow:DeepSea AUC: 0.975651313224623
# INFO:tensorflow:
# INFO:tensorflow:13000 0.44645184
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9659015915484532
# INFO:tensorflow:DeepSea AUC: 0.9752603700038416
# INFO:tensorflow:
# INFO:tensorflow:14000 0.31923112
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9749789237989066
# INFO:tensorflow:DeepSea AUC: 0.9807971839194922
# INFO:tensorflow:
# INFO:tensorflow:15000 0.38930595
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9616056293988362
# INFO:tensorflow:DeepSea AUC: 0.9685719849480945
# INFO:tensorflow:
# INFO:tensorflow:16000 0.40467635
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.970531477774923
# INFO:tensorflow:DeepSea AUC: 0.9718567707014425
# INFO:tensorflow:
# INFO:tensorflow:17000 0.09894116
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9438666732984299
# INFO:tensorflow:DeepSea AUC: 0.9535429843969566
# INFO:tensorflow:
# INFO:tensorflow:18000 0.14016595
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9652178641679025
# INFO:tensorflow:DeepSea AUC: 0.9684926988014874
# INFO:tensorflow:
# INFO:tensorflow:19000 0.07772241
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9438799015096042
# INFO:tensorflow:DeepSea AUC: 0.9472671400283345
# INFO:tensorflow:
# INFO:tensorflow:20000 0.05787089
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9692924276657001
# INFO:tensorflow:DeepSea AUC: 0.9722992174746908
# INFO:tensorflow:
# INFO:tensorflow:21000 0.25144094
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9655276037944791
# INFO:tensorflow:DeepSea AUC: 0.9691902622517561
# INFO:tensorflow:
# INFO:tensorflow:22000 0.03994077
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9712735426053984
# INFO:tensorflow:DeepSea AUC: 0.97706598237328
# INFO:tensorflow:
# INFO:tensorflow:23000 0.38710144
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9377570405645641
# INFO:tensorflow:DeepSea AUC: 0.9507516180216828
# INFO:tensorflow:
# INFO:tensorflow:24000 0.08596695
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9650312779614085
# INFO:tensorflow:DeepSea AUC: 0.9688463651246316
# INFO:tensorflow:
# INFO:tensorflow:25000 0.27172944
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.963010245920827
# INFO:tensorflow:DeepSea AUC: 0.9653659396081704
# INFO:tensorflow:
# INFO:tensorflow:26000 0.048377935
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9382475885890087
# INFO:tensorflow:DeepSea AUC: 0.9366060798437554
# INFO:tensorflow:
# INFO:tensorflow:27000 0.11626537
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.959926863046813
# INFO:tensorflow:DeepSea AUC: 0.963060970766895
# INFO:tensorflow:
# INFO:tensorflow:28000 0.26547304
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9588682943676697
# INFO:tensorflow:DeepSea AUC: 0.962399645780474
# INFO:tensorflow:
# INFO:tensorflow:29000 0.1484056
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9479339691151333
# INFO:tensorflow:DeepSea AUC: 0.9582773654151625
# INFO:tensorflow:
# INFO:tensorflow:30000 0.08008397
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9568601267405279
# INFO:tensorflow:DeepSea AUC: 0.9643507024920923
# INFO:tensorflow:
# INFO:tensorflow:31000 0.23551083
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9453465589627671
# INFO:tensorflow:DeepSea AUC: 0.9595750590502465
# INFO:tensorflow:
# INFO:tensorflow:32000 1.4309044
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.95003423130743
# INFO:tensorflow:DeepSea AUC: 0.9495996633158815
# INFO:tensorflow:
# INFO:tensorflow:33000 0.044786844
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9634072680310483
# INFO:tensorflow:DeepSea AUC: 0.9656279907779073
# INFO:tensorflow:
# INFO:tensorflow:34000 0.07779675
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9727914191635113
# INFO:tensorflow:DeepSea AUC: 0.9782475586794412
# INFO:tensorflow:
# INFO:tensorflow:35000 2.121548
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9803418129213388
# INFO:tensorflow:DeepSea AUC: 0.9820771282686305
# INFO:tensorflow:
# INFO:tensorflow:36000 0.04560224
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.976943898061188
# INFO:tensorflow:DeepSea AUC: 0.9790073642988221
# INFO:tensorflow:
# INFO:tensorflow:37000 0.06469065
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9700629801584049
# INFO:tensorflow:DeepSea AUC: 0.9726059070409424
# INFO:tensorflow:
# INFO:tensorflow:38000 0.5152911
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9753681462877956
# INFO:tensorflow:DeepSea AUC: 0.976179540000454
# INFO:tensorflow:
# INFO:tensorflow:39000 0.22798255
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9731751184169288
# INFO:tensorflow:DeepSea AUC: 0.9763844516568655
# INFO:tensorflow:
# INFO:tensorflow:40000 0.19989765
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9674166467936439
# INFO:tensorflow:DeepSea AUC: 0.9703837104433042
# INFO:tensorflow:
# INFO:tensorflow:Starting Training
# INFO:tensorflow:41000 0.30784875
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9829835751667821
# INFO:tensorflow:DeepSea AUC: 0.9839761072565137
# INFO:tensorflow:
# INFO:tensorflow:42000 1.2873012
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9552500118445049
# INFO:tensorflow:DeepSea AUC: 0.9545520803018697
# INFO:tensorflow:
# INFO:tensorflow:43000 0.13862063
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9797944812323918
# INFO:tensorflow:DeepSea AUC: 0.9812644944543856
# INFO:tensorflow:
# INFO:tensorflow:44000 0.15445451
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9692766346251287
# INFO:tensorflow:DeepSea AUC: 0.9638276362809758
# INFO:tensorflow:
# INFO:tensorflow:45000 0.49118474
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.962056111529602
# INFO:tensorflow:DeepSea AUC: 0.9634282491561361
# INFO:tensorflow:
# INFO:tensorflow:46000 0.04537033
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9666345346930728
# INFO:tensorflow:DeepSea AUC: 0.9642843386638182
# INFO:tensorflow:
# INFO:tensorflow:47000 0.6543706
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9697024033159185
# INFO:tensorflow:DeepSea AUC: 0.9679291568346481
# INFO:tensorflow:
# INFO:tensorflow:48000 0.41626716
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9638930998793457
# INFO:tensorflow:DeepSea AUC: 0.9590077390831022
# INFO:tensorflow:
# INFO:tensorflow:49000 0.12392782
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9752847251593293
# INFO:tensorflow:DeepSea AUC: 0.9732557994375245
# INFO:tensorflow:
# INFO:tensorflow:50000 0.1279182
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9656882083204829
# INFO:tensorflow:DeepSea AUC: 0.9665495303991258
# INFO:tensorflow:
# INFO:tensorflow:51000 0.30879286
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9779793474795668
# INFO:tensorflow:DeepSea AUC: 0.9745122914383743
# INFO:tensorflow:
# INFO:tensorflow:52000 0.042766742
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9635586120415094
# INFO:tensorflow:DeepSea AUC: 0.9659993520392898
# INFO:tensorflow:
# INFO:tensorflow:53000 0.1739893
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.971796964758171
# INFO:tensorflow:DeepSea AUC: 0.9696383207749399
# INFO:tensorflow:
# INFO:tensorflow:54000 0.37787905
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9700599249380192
# INFO:tensorflow:DeepSea AUC: 0.9674656211640514
# INFO:tensorflow:
# INFO:tensorflow:55000 0.18750845
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9816653818332673
# INFO:tensorflow:DeepSea AUC: 0.9804013362687495
# INFO:tensorflow:
# INFO:tensorflow:56000 0.1286299
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9555697594851811
# INFO:tensorflow:DeepSea AUC: 0.9561572637079102
# INFO:tensorflow:
# INFO:tensorflow:57000 0.089644425
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9621117317853628
# INFO:tensorflow:DeepSea AUC: 0.9624254657226413
# INFO:tensorflow:
# INFO:tensorflow:58000 0.21383055
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9756573053971453
# INFO:tensorflow:DeepSea AUC: 0.9758324066546488
# INFO:tensorflow:
# INFO:tensorflow:59000 0.70072824
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9730872992893318
# INFO:tensorflow:DeepSea AUC: 0.9729545051535441
# INFO:tensorflow:
# INFO:tensorflow:60000 0.059197754
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.976855992276723
# INFO:tensorflow:DeepSea AUC: 0.9780647467508929
# INFO:tensorflow:
# INFO:tensorflow:61000 0.21673669
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9791069048262946
# INFO:tensorflow:DeepSea AUC: 0.9781379450916543
# INFO:tensorflow:
# INFO:tensorflow:62000 1.7997766
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9699219758979243
# INFO:tensorflow:DeepSea AUC: 0.9675698057878523
# INFO:tensorflow:
# INFO:tensorflow:63000 0.11888884
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9766797876706769
# INFO:tensorflow:DeepSea AUC: 0.975651313224623
# INFO:tensorflow:
# INFO:tensorflow:64000 0.13320972
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9757965814972132
# INFO:tensorflow:DeepSea AUC: 0.9752603700038416
# INFO:tensorflow:
# INFO:tensorflow:65000 0.06969565
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9809179808576882
# INFO:tensorflow:DeepSea AUC: 0.9807971839194922
# INFO:tensorflow:
# INFO:tensorflow:66000 0.09446583
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.970826168208482
# INFO:tensorflow:DeepSea AUC: 0.9685719849480945
# INFO:tensorflow:
# INFO:tensorflow:67000 0.044019215
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9749457832323154
# INFO:tensorflow:DeepSea AUC: 0.9718567707014425
# INFO:tensorflow:
# INFO:tensorflow:68000 0.42929268
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9526004193357597
# INFO:tensorflow:DeepSea AUC: 0.9535429843969566
# INFO:tensorflow:
# INFO:tensorflow:69000 0.25120172
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9692902006175488
# INFO:tensorflow:DeepSea AUC: 0.9684926988014874
# INFO:tensorflow:
# INFO:tensorflow:70000 0.05689407
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9495136136490195
# INFO:tensorflow:DeepSea AUC: 0.9472671400283345
# INFO:tensorflow:
# INFO:tensorflow:71000 0.03595506
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9727808522121324
# INFO:tensorflow:DeepSea AUC: 0.9722992174746908
# INFO:tensorflow:
# INFO:tensorflow:72000 0.046615385
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9683887823140602
# INFO:tensorflow:DeepSea AUC: 0.9691902622517561
# INFO:tensorflow:
# INFO:tensorflow:73000 1.5899862
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9768394467155461
# INFO:tensorflow:DeepSea AUC: 0.97706598237328
# INFO:tensorflow:
# INFO:tensorflow:74000 0.10774255
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9600066944426144
# INFO:tensorflow:DeepSea AUC: 0.9507516180216828
# INFO:tensorflow:
# INFO:tensorflow:75000 0.06736388
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.970828062188771
# INFO:tensorflow:DeepSea AUC: 0.9688463651246316
# INFO:tensorflow:
# INFO:tensorflow:76000 0.042203132
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9657766897751474
# INFO:tensorflow:DeepSea AUC: 0.9653659396081704
# INFO:tensorflow:
# INFO:tensorflow:77000 0.7203558
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9423027025086809
# INFO:tensorflow:DeepSea AUC: 0.9366060798437554
# INFO:tensorflow:
# INFO:tensorflow:78000 0.021251366
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9617787054031754
# INFO:tensorflow:DeepSea AUC: 0.963060970766895
# INFO:tensorflow:
# INFO:tensorflow:79000 0.11000591
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9651362960397855
# INFO:tensorflow:DeepSea AUC: 0.962399645780474
# INFO:tensorflow:
# INFO:tensorflow:80000 0.41541803
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.962931776210516
# INFO:tensorflow:DeepSea AUC: 0.9582773654151625
# INFO:tensorflow:
# INFO:tensorflow:Initializing variables
# INFO:tensorflow:Starting Training
# INFO:tensorflow:1000 0.28419816
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9514702765661693
# INFO:tensorflow:DeepSea AUC: 0.9620867257941046
# INFO:tensorflow:
# INFO:tensorflow:2000 0.08448218
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9497481925314968
# INFO:tensorflow:DeepSea AUC: 0.9677369907295043
# INFO:tensorflow:
# INFO:tensorflow:3000 1.0530121
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9566491167014683
# INFO:tensorflow:DeepSea AUC: 0.9646915390550616
# INFO:tensorflow:
# INFO:tensorflow:4000 0.10106354
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9684710347923575
# INFO:tensorflow:DeepSea AUC: 0.9759615244322536
# INFO:tensorflow:
# INFO:tensorflow:5000 0.3244799
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9458433526753627
# INFO:tensorflow:DeepSea AUC: 0.9536763676645692
# INFO:tensorflow:
# INFO:tensorflow:6000 0.68581325
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9436094533685451
# INFO:tensorflow:DeepSea AUC: 0.9591916891040928
# INFO:tensorflow:
# INFO:tensorflow:7000 0.050709542
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.966615747480426
# INFO:tensorflow:DeepSea AUC: 0.9724624825691495
# INFO:tensorflow:
# INFO:tensorflow:8000 0.2785288
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9635346210375921
# INFO:tensorflow:DeepSea AUC: 0.970517947658467
# INFO:tensorflow:
# INFO:tensorflow:9000 0.06479123
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9701802636892642
# INFO:tensorflow:DeepSea AUC: 0.9762803063750364
# INFO:tensorflow:
# INFO:tensorflow:10000 0.1396971
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9729846316527873
# INFO:tensorflow:DeepSea AUC: 0.9756585739444428
# INFO:tensorflow:
# INFO:tensorflow:11000 0.26849952
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9527975577624146
# INFO:tensorflow:DeepSea AUC: 0.9662792317611295
# INFO:tensorflow:
# INFO:tensorflow:12000 0.25143036
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9580309818937851
# INFO:tensorflow:DeepSea AUC: 0.9745449448219826
# INFO:tensorflow:
# INFO:tensorflow:13000 0.60374534
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9654983869820023
# INFO:tensorflow:DeepSea AUC: 0.9726486304149087
# INFO:tensorflow:
# INFO:tensorflow:14000 0.4294009
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9731453538948536
# INFO:tensorflow:DeepSea AUC: 0.9808232201141835
# INFO:tensorflow:
# INFO:tensorflow:15000 0.46543834
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9587872323831709
# INFO:tensorflow:DeepSea AUC: 0.9665616645653838
# INFO:tensorflow:
# INFO:tensorflow:16000 0.5338144
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9630128744250217
# INFO:tensorflow:DeepSea AUC: 0.9699870818443357
# INFO:tensorflow:
# INFO:tensorflow:17000 0.16525716
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9529128070099852
# INFO:tensorflow:DeepSea AUC: 0.9613165574538866
# INFO:tensorflow:
# INFO:tensorflow:18000 0.18591267
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9622020020270832
# INFO:tensorflow:DeepSea AUC: 0.9662227532929052
# INFO:tensorflow:
# INFO:tensorflow:19000 0.12378792
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9380068562269612
# INFO:tensorflow:DeepSea AUC: 0.9470536211307637
# INFO:tensorflow:
# INFO:tensorflow:20000 0.090762235
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9641545606831311
# INFO:tensorflow:DeepSea AUC: 0.9701425309138793
# INFO:tensorflow:
# INFO:tensorflow:21000 0.35693073
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.964741661717734
# INFO:tensorflow:DeepSea AUC: 0.9678404937616276
# INFO:tensorflow:
# INFO:tensorflow:22000 0.06497373
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9697863082464157
# INFO:tensorflow:DeepSea AUC: 0.9756211699423483
# INFO:tensorflow:
# INFO:tensorflow:23000 0.5232372
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9442602472504691
# INFO:tensorflow:DeepSea AUC: 0.951304070653357
# INFO:tensorflow:
# INFO:tensorflow:24000 0.13356696
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9614925859543715
# INFO:tensorflow:DeepSea AUC: 0.9673444732617807
# INFO:tensorflow:
# INFO:tensorflow:25000 0.3529911
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9598465936425964
# INFO:tensorflow:DeepSea AUC: 0.9640630446109537
# INFO:tensorflow:
# INFO:tensorflow:26000 0.070846744
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9316055073532653
# INFO:tensorflow:DeepSea AUC: 0.9362667109351865
# INFO:tensorflow:
# INFO:tensorflow:27000 0.19560233
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9562429209715901
# INFO:tensorflow:DeepSea AUC: 0.9638995932117697
# INFO:tensorflow:
# INFO:tensorflow:28000 0.3260242
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9569943950313426
# INFO:tensorflow:DeepSea AUC: 0.96228141007278
# INFO:tensorflow:
# INFO:tensorflow:29000 0.22073191
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9461817037995822
# INFO:tensorflow:DeepSea AUC: 0.9578703230508284
# INFO:tensorflow:
# INFO:tensorflow:30000 0.17737606
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.952994869557879
# INFO:tensorflow:DeepSea AUC: 0.9611943211283515
# INFO:tensorflow:
# INFO:tensorflow:31000 0.32060203
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.941168180197981
# INFO:tensorflow:DeepSea AUC: 0.9564873625230714
# INFO:tensorflow:
# INFO:tensorflow:32000 1.9721893
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9387635846321432
# INFO:tensorflow:DeepSea AUC: 0.9469826582158463
# INFO:tensorflow:
# INFO:tensorflow:33000 0.086912744
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9559799410712324
# INFO:tensorflow:DeepSea AUC: 0.9634229639030863
# INFO:tensorflow:
# INFO:tensorflow:34000 0.12474817
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9696276858060539
# INFO:tensorflow:DeepSea AUC: 0.9756506285165373
# INFO:tensorflow:
# INFO:tensorflow:35000 2.5682175
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9779972122753429
# INFO:tensorflow:DeepSea AUC: 0.9809928110564405
# INFO:tensorflow:
# INFO:tensorflow:36000 0.061314333
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.973168746685622
# INFO:tensorflow:DeepSea AUC: 0.9772994132161518
# INFO:tensorflow:
# INFO:tensorflow:37000 0.13123465
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9668398048812366
# INFO:tensorflow:DeepSea AUC: 0.9723789638110135
# INFO:tensorflow:
# INFO:tensorflow:38000 0.53929824
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9738297485477763
# INFO:tensorflow:DeepSea AUC: 0.9779445921102824
# INFO:tensorflow:
# INFO:tensorflow:39000 0.3498825
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9707113077468942
# INFO:tensorflow:DeepSea AUC: 0.9739324879202071
# INFO:tensorflow:
# INFO:tensorflow:40000 0.22926165
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9661901046460296
# INFO:tensorflow:DeepSea AUC: 0.9707340147981274
# INFO:tensorflow:
# INFO:tensorflow:Starting Training
# INFO:tensorflow:41000 0.40244082
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9802880595074003
# INFO:tensorflow:DeepSea AUC: 0.9823176400605796
# INFO:tensorflow:
# INFO:tensorflow:42000 1.407887
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9536245116724476
# INFO:tensorflow:DeepSea AUC: 0.9562716144695291
# INFO:tensorflow:
# INFO:tensorflow:43000 0.19963188
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9761833588554629
# INFO:tensorflow:DeepSea AUC: 0.9782192563676418
# INFO:tensorflow:
# INFO:tensorflow:44000 0.20887457
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9612878353103496
# INFO:tensorflow:DeepSea AUC: 0.961935944528663
# INFO:tensorflow:
# INFO:tensorflow:45000 0.42381522
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9595083992139181
# INFO:tensorflow:DeepSea AUC: 0.9628985246253129
# INFO:tensorflow:
# INFO:tensorflow:46000 0.08962567
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9545565874606825
# INFO:tensorflow:DeepSea AUC: 0.9609305624036799
# INFO:tensorflow:
# INFO:tensorflow:47000 0.8842138
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9620666000946143
# INFO:tensorflow:DeepSea AUC: 0.9647125139356325
# INFO:tensorflow:
# INFO:tensorflow:48000 0.6000098
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.957379906389595
# INFO:tensorflow:DeepSea AUC: 0.9594149227720545
# INFO:tensorflow:
# INFO:tensorflow:49000 0.16925657
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9688236509079506
# INFO:tensorflow:DeepSea AUC: 0.9709825051889511
# INFO:tensorflow:
# INFO:tensorflow:50000 0.16873133
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9632419271078896
# INFO:tensorflow:DeepSea AUC: 0.965690772016097
# INFO:tensorflow:
# INFO:tensorflow:51000 0.43488526
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9768074218592417
# INFO:tensorflow:DeepSea AUC: 0.9758275988685493
# INFO:tensorflow:
# INFO:tensorflow:52000 0.061408922
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9579237186652398
# INFO:tensorflow:DeepSea AUC: 0.9620867257941046
# INFO:tensorflow:
# INFO:tensorflow:53000 0.2683196
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9660356093501412
# INFO:tensorflow:DeepSea AUC: 0.9677369907295043
# INFO:tensorflow:
# INFO:tensorflow:54000 0.38784018
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.962964832937367
# INFO:tensorflow:DeepSea AUC: 0.9646915390550616
# INFO:tensorflow:
# INFO:tensorflow:55000 0.36174002
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9756360486647627
# INFO:tensorflow:DeepSea AUC: 0.9759615244322536
# INFO:tensorflow:
# INFO:tensorflow:56000 0.24132974
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9496587986704019
# INFO:tensorflow:DeepSea AUC: 0.9536763676645692
# INFO:tensorflow:
# INFO:tensorflow:57000 0.15227157
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9554914645235711
# INFO:tensorflow:DeepSea AUC: 0.9591916891040928
# INFO:tensorflow:
# INFO:tensorflow:58000 0.2354317
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9714733401904229
# INFO:tensorflow:DeepSea AUC: 0.9724624825691495
# INFO:tensorflow:
# INFO:tensorflow:59000 0.7135811
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.969473681872771
# INFO:tensorflow:DeepSea AUC: 0.970517947658467
# INFO:tensorflow:
# INFO:tensorflow:60000 0.09679367
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9744558244108212
# INFO:tensorflow:DeepSea AUC: 0.9762803063750364
# INFO:tensorflow:
# INFO:tensorflow:61000 0.2912757
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9741268668560417
# INFO:tensorflow:DeepSea AUC: 0.9756585739444428
# INFO:tensorflow:
# INFO:tensorflow:62000 2.1052065
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9652171673829931
# INFO:tensorflow:DeepSea AUC: 0.9662792317611295
# INFO:tensorflow:
# INFO:tensorflow:63000 0.21726099
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9731328741724501
# INFO:tensorflow:DeepSea AUC: 0.9745449448219826
# INFO:tensorflow:
# INFO:tensorflow:64000 0.17310889
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9711432193764229
# INFO:tensorflow:DeepSea AUC: 0.9726486304149087
# INFO:tensorflow:
# INFO:tensorflow:65000 0.12520905
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9791411312590991
# INFO:tensorflow:DeepSea AUC: 0.9808232201141835
# INFO:tensorflow:
# INFO:tensorflow:66000 0.15218918
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9655663184566493
# INFO:tensorflow:DeepSea AUC: 0.9665616645653838
# INFO:tensorflow:
# INFO:tensorflow:67000 0.075105004
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9689815815099703
# INFO:tensorflow:DeepSea AUC: 0.9699870818443357
# INFO:tensorflow:
# INFO:tensorflow:68000 0.46678448
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9584898264998643
# INFO:tensorflow:DeepSea AUC: 0.9613165574538866
# INFO:tensorflow:
# INFO:tensorflow:69000 0.29880098
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9651080491161675
# INFO:tensorflow:DeepSea AUC: 0.9662227532929052
# INFO:tensorflow:
# INFO:tensorflow:70000 0.085346065
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9434957521006493
# INFO:tensorflow:DeepSea AUC: 0.9470536211307637
# INFO:tensorflow:
# INFO:tensorflow:71000 0.07897535
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9683795744464417
# INFO:tensorflow:DeepSea AUC: 0.9701425309138793
# INFO:tensorflow:
# INFO:tensorflow:72000 0.07465396
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9669135803468112
# INFO:tensorflow:DeepSea AUC: 0.9678404937616276
# INFO:tensorflow:
# INFO:tensorflow:73000 2.3310668
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9733964714604839
# INFO:tensorflow:DeepSea AUC: 0.9756211699423483
# INFO:tensorflow:
# INFO:tensorflow:74000 0.18144886
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.95188973240663
# INFO:tensorflow:DeepSea AUC: 0.951304070653357
# INFO:tensorflow:
# INFO:tensorflow:75000 0.10243697
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9667235184238119
# INFO:tensorflow:DeepSea AUC: 0.9673444732617807
# INFO:tensorflow:
# INFO:tensorflow:76000 0.07451211
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9630145265344074
# INFO:tensorflow:DeepSea AUC: 0.9640630446109537
# INFO:tensorflow:
# INFO:tensorflow:77000 0.8271248
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9355368125041845
# INFO:tensorflow:DeepSea AUC: 0.9362667109351865
# INFO:tensorflow:
# INFO:tensorflow:78000 0.040569935
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.960183060166796
# INFO:tensorflow:DeepSea AUC: 0.9638995932117697
# INFO:tensorflow:
# INFO:tensorflow:79000 0.19123474
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9609449454330126
# INFO:tensorflow:DeepSea AUC: 0.96228141007278
# INFO:tensorflow:
# INFO:tensorflow:80000 0.52079386
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9582048125782523
# INFO:tensorflow:DeepSea AUC: 0.9578703230508284
# INFO:tensorflow:
# INFO:tensorflow:Initializing variables
# INFO:tensorflow:Starting Training
# INFO:tensorflow:1000 0.26106423
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.948832839853489
# INFO:tensorflow:DeepSea AUC: 0.9628615490488925
# INFO:tensorflow:
# INFO:tensorflow:2000 0.07455996
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9539777570694215
# INFO:tensorflow:DeepSea AUC: 0.9684711231920221
# INFO:tensorflow:
# INFO:tensorflow:3000 1.0180241
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9574802603308897
# INFO:tensorflow:DeepSea AUC: 0.9660051757671957
# INFO:tensorflow:
# INFO:tensorflow:4000 0.07578802
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9705172127838942
# INFO:tensorflow:DeepSea AUC: 0.9763361515476294
# INFO:tensorflow:
# INFO:tensorflow:5000 0.30476373
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.947594091776225
# INFO:tensorflow:DeepSea AUC: 0.9552062619635784
# INFO:tensorflow:
# INFO:tensorflow:6000 0.6755476
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9483916096647922
# INFO:tensorflow:DeepSea AUC: 0.9602938324061094
# INFO:tensorflow:
# INFO:tensorflow:7000 0.045221895
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9670356618322098
# INFO:tensorflow:DeepSea AUC: 0.9730166871366464
# INFO:tensorflow:
# INFO:tensorflow:8000 0.24326706
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9611258286300548
# INFO:tensorflow:DeepSea AUC: 0.9706523502529534
# INFO:tensorflow:
# INFO:tensorflow:9000 0.052327275
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9695158172453799
# INFO:tensorflow:DeepSea AUC: 0.9768219004472104
# INFO:tensorflow:
# INFO:tensorflow:10000 0.22513977
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9783175682913036
# INFO:tensorflow:DeepSea AUC: 0.9775837796991041
# INFO:tensorflow:
# INFO:tensorflow:11000 0.2875155
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9536200124691098
# INFO:tensorflow:DeepSea AUC: 0.968049002360085
# INFO:tensorflow:
# INFO:tensorflow:12000 0.22106755
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9647560466685491
# INFO:tensorflow:DeepSea AUC: 0.9755578940429439
# INFO:tensorflow:
# INFO:tensorflow:13000 0.704443
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9673247406544444
# INFO:tensorflow:DeepSea AUC: 0.9750435979009925
# INFO:tensorflow:
# INFO:tensorflow:14000 0.4423272
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9662556936159076
# INFO:tensorflow:DeepSea AUC: 0.980314884894019
# INFO:tensorflow:
# INFO:tensorflow:15000 0.48436284
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9605087175793522
# INFO:tensorflow:DeepSea AUC: 0.9681572505679501
# INFO:tensorflow:
# INFO:tensorflow:16000 0.52627707
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9663506373259669
# INFO:tensorflow:DeepSea AUC: 0.9701029360103206
# INFO:tensorflow:
# INFO:tensorflow:17000 0.13883397
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9482272397074661
# INFO:tensorflow:DeepSea AUC: 0.9539646056494455
# INFO:tensorflow:
# INFO:tensorflow:18000 0.192558
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9635456697604873
# INFO:tensorflow:DeepSea AUC: 0.9667403914870957
# INFO:tensorflow:
# INFO:tensorflow:19000 0.108671464
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9436392111300317
# INFO:tensorflow:DeepSea AUC: 0.9499560693162823
# INFO:tensorflow:
# INFO:tensorflow:20000 0.09416091
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9667624133897593
# INFO:tensorflow:DeepSea AUC: 0.9711605506045519
# INFO:tensorflow:
# INFO:tensorflow:21000 0.32283905
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9664667089098467
# INFO:tensorflow:DeepSea AUC: 0.9699138669883104
# INFO:tensorflow:
# INFO:tensorflow:22000 0.060346615
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9695782403481622
# INFO:tensorflow:DeepSea AUC: 0.9761847756492747
# INFO:tensorflow:
# INFO:tensorflow:23000 0.4026662
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.945955448077904
# INFO:tensorflow:DeepSea AUC: 0.9521285292148965
# INFO:tensorflow:
# INFO:tensorflow:24000 0.14485936
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.962401161128761
# INFO:tensorflow:DeepSea AUC: 0.9673523867561991
# INFO:tensorflow:
# INFO:tensorflow:25000 0.34416473
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.962758820187381
# INFO:tensorflow:DeepSea AUC: 0.9646937762275227
# INFO:tensorflow:
# INFO:tensorflow:26000 0.07870958
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9351580292708774
# INFO:tensorflow:DeepSea AUC: 0.9394740142767602
# INFO:tensorflow:
# INFO:tensorflow:27000 0.19882973
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.961591561066084
# INFO:tensorflow:DeepSea AUC: 0.9650395588587869
# INFO:tensorflow:
# INFO:tensorflow:28000 0.28345793
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.959980695957298
# INFO:tensorflow:DeepSea AUC: 0.962656194323019
# INFO:tensorflow:
# INFO:tensorflow:29000 0.22762112
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9518643876342439
# INFO:tensorflow:DeepSea AUC: 0.9593238834820405
# INFO:tensorflow:
# INFO:tensorflow:30000 0.12480806
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9527892742558828
# INFO:tensorflow:DeepSea AUC: 0.9627197486081742
# INFO:tensorflow:
# INFO:tensorflow:31000 0.3490126
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9426419027898026
# INFO:tensorflow:DeepSea AUC: 0.9576209867332061
# INFO:tensorflow:
# INFO:tensorflow:32000 2.1864326
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9450566554388723
# INFO:tensorflow:DeepSea AUC: 0.949655909407014
# INFO:tensorflow:
# INFO:tensorflow:33000 0.06703235
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9590510436448281
# INFO:tensorflow:DeepSea AUC: 0.9642256147130768
# INFO:tensorflow:
# INFO:tensorflow:34000 0.117553584
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9709435427498468
# INFO:tensorflow:DeepSea AUC: 0.9766451983307761
# INFO:tensorflow:
# INFO:tensorflow:35000 2.7299788
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9775219475571086
# INFO:tensorflow:DeepSea AUC: 0.9809945605568736
# INFO:tensorflow:
# INFO:tensorflow:36000 0.052371297
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9744638253684854
# INFO:tensorflow:DeepSea AUC: 0.9785763797609368
# INFO:tensorflow:
# INFO:tensorflow:37000 0.12474735
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9672066302880133
# INFO:tensorflow:DeepSea AUC: 0.9710951799339004
# INFO:tensorflow:
# INFO:tensorflow:38000 0.4548017
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9699700692119635
# INFO:tensorflow:DeepSea AUC: 0.9754052466884755
# INFO:tensorflow:
# INFO:tensorflow:39000 0.3393287
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9717777654445596
# INFO:tensorflow:DeepSea AUC: 0.9750691416987367
# INFO:tensorflow:
# INFO:tensorflow:40000 0.24760467
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9703565829782924
# INFO:tensorflow:DeepSea AUC: 0.9717497856515073
# INFO:tensorflow:
# INFO:tensorflow:Starting Training
# INFO:tensorflow:41000 0.4519194
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9827067638029666
# INFO:tensorflow:DeepSea AUC: 0.9826560179571615
# INFO:tensorflow:
# INFO:tensorflow:42000 1.4269289
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9587457693877734
# INFO:tensorflow:DeepSea AUC: 0.9593231506883226
# INFO:tensorflow:
# INFO:tensorflow:43000 0.20986319
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9768236883062466
# INFO:tensorflow:DeepSea AUC: 0.9792098811942088
# INFO:tensorflow:
# INFO:tensorflow:44000 0.19949861
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9621588917985575
# INFO:tensorflow:DeepSea AUC: 0.9632250756089066
# INFO:tensorflow:
# INFO:tensorflow:45000 0.41864112
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9637679629360689
# INFO:tensorflow:DeepSea AUC: 0.9631744530127075
# INFO:tensorflow:
# INFO:tensorflow:46000 0.08228661
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9591920563828147
# INFO:tensorflow:DeepSea AUC: 0.962559979804577
# INFO:tensorflow:
# INFO:tensorflow:47000 0.61673635
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9634550725370654
# INFO:tensorflow:DeepSea AUC: 0.9651520454781081
# INFO:tensorflow:
# INFO:tensorflow:48000 0.58964586
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9623118709190854
# INFO:tensorflow:DeepSea AUC: 0.9605257156168726
# INFO:tensorflow:
# INFO:tensorflow:49000 0.16209184
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9711329562871962
# INFO:tensorflow:DeepSea AUC: 0.9716835180204811
# INFO:tensorflow:
# INFO:tensorflow:50000 0.1745611
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9655046938756113
# INFO:tensorflow:DeepSea AUC: 0.9663733083029121
# INFO:tensorflow:
# INFO:tensorflow:51000 0.27991456
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9765335670409719
# INFO:tensorflow:DeepSea AUC: 0.9748655915153591
# INFO:tensorflow:
# INFO:tensorflow:52000 0.06334708
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9587445129175555
# INFO:tensorflow:DeepSea AUC: 0.9628615490488925
# INFO:tensorflow:
# INFO:tensorflow:53000 0.25649396
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9683221287444113
# INFO:tensorflow:DeepSea AUC: 0.9684711231920221
# INFO:tensorflow:
# INFO:tensorflow:54000 0.35262528
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9668937570588066
# INFO:tensorflow:DeepSea AUC: 0.9660051757671957
# INFO:tensorflow:
# INFO:tensorflow:55000 0.41021404
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9770033622571643
# INFO:tensorflow:DeepSea AUC: 0.9763361515476294
# INFO:tensorflow:
# INFO:tensorflow:56000 0.22593367
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9529432768315798
# INFO:tensorflow:DeepSea AUC: 0.9552062619635784
# INFO:tensorflow:
# INFO:tensorflow:57000 0.13554572
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9591389145017832
# INFO:tensorflow:DeepSea AUC: 0.9602938324061094
# INFO:tensorflow:
# INFO:tensorflow:58000 0.1863255
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9731132021535011
# INFO:tensorflow:DeepSea AUC: 0.9730166871366464
# INFO:tensorflow:
# INFO:tensorflow:59000 0.63270307
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9707418010908739
# INFO:tensorflow:DeepSea AUC: 0.9706523502529534
# INFO:tensorflow:
# INFO:tensorflow:60000 0.08679157
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9740458856852052
# INFO:tensorflow:DeepSea AUC: 0.9768219004472104
# INFO:tensorflow:
# INFO:tensorflow:61000 0.29103386
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9790526324056972
# INFO:tensorflow:DeepSea AUC: 0.9775837796991041
# INFO:tensorflow:
# INFO:tensorflow:62000 2.1495683
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.968108845821309
# INFO:tensorflow:DeepSea AUC: 0.968049002360085
# INFO:tensorflow:
# INFO:tensorflow:63000 0.18766402
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9774629316074506
# INFO:tensorflow:DeepSea AUC: 0.9755578940429439
# INFO:tensorflow:
# INFO:tensorflow:64000 0.16133407
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9740706063292718
# INFO:tensorflow:DeepSea AUC: 0.9750435979009925
# INFO:tensorflow:
# INFO:tensorflow:65000 0.11110502
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9816539480884166
# INFO:tensorflow:DeepSea AUC: 0.980314884894019
# INFO:tensorflow:
# INFO:tensorflow:66000 0.18924701
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9704401857565369
# INFO:tensorflow:DeepSea AUC: 0.9681572505679501
# INFO:tensorflow:
# INFO:tensorflow:67000 0.06973014
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9693190999422683
# INFO:tensorflow:DeepSea AUC: 0.9701029360103206
# INFO:tensorflow:
# INFO:tensorflow:68000 0.54779816
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9527752799964948
# INFO:tensorflow:DeepSea AUC: 0.9539646056494455
# INFO:tensorflow:
# INFO:tensorflow:69000 0.2844325
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9660500858011654
# INFO:tensorflow:DeepSea AUC: 0.9667403914870957
# INFO:tensorflow:
# INFO:tensorflow:70000 0.08036392
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9494713711740632
# INFO:tensorflow:DeepSea AUC: 0.9499560693162823
# INFO:tensorflow:
# INFO:tensorflow:71000 0.07634046
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9699365091480052
# INFO:tensorflow:DeepSea AUC: 0.9711605506045519
# INFO:tensorflow:
# INFO:tensorflow:72000 0.070178725
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9687937173608058
# INFO:tensorflow:DeepSea AUC: 0.9699138669883104
# INFO:tensorflow:
# INFO:tensorflow:73000 2.3436515
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9751017512112741
# INFO:tensorflow:DeepSea AUC: 0.9761847756492747
# INFO:tensorflow:
# INFO:tensorflow:74000 0.16352694
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.956286719437689
# INFO:tensorflow:DeepSea AUC: 0.9521285292148965
# INFO:tensorflow:
# INFO:tensorflow:75000 0.0862273
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9660968433227768
# INFO:tensorflow:DeepSea AUC: 0.9673523867561991
# INFO:tensorflow:
# INFO:tensorflow:76000 0.05944837
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9663179205881064
# INFO:tensorflow:DeepSea AUC: 0.9646937762275227
# INFO:tensorflow:
# INFO:tensorflow:77000 0.91588473
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9394294119167527
# INFO:tensorflow:DeepSea AUC: 0.9394740142767602
# INFO:tensorflow:
# INFO:tensorflow:78000 0.041983247
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9682526010053617
# INFO:tensorflow:DeepSea AUC: 0.9650395588587869
# INFO:tensorflow:
# INFO:tensorflow:79000 0.1873229
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9635628314553524
# INFO:tensorflow:DeepSea AUC: 0.962656194323019
# INFO:tensorflow:
# INFO:tensorflow:80000 0.48025087
# INFO:tensorflow:On validation
# INFO:tensorflow:Our AUC:     0.9617702874619553
# INFO:tensorflow:DeepSea AUC: 0.9593238834820405
# INFO:tensorflow:

# %%
# P(TF1 && TF2)
eq_aucs = []
eq_prcs = []
# P(TF1 && !TF2)
j10_aucs = []
j10_prcs = []
# P(TF2|TF1)
aucs = []
prcs = []
# P(TF2|TF1=0)
cond0_aucs = []
cond0_prcs = []
# P(TF2|TF1=0)
cond1_aucs = []
cond1_prcs = []

twoway_preds = []

for i, mlp in enumerate(mlps):
    ds = mlp.make_alt_dataset(test_data, 64, 1, 10, paramaterized_imputation_gen(position_mask([i]), 3*19))
    deepsea, preds, truth, _ = mlp.test(30000, log=True, iterator_handle=ds)
    for j in range(19):
        if i == j: continue
        deepsea_pred = deepsea[:,i]*deepsea[:,j] #P(TFi|S)P(TFj|S)
        our_pred = deepsea[:,i]*preds[:,j] #P(TFi|S)P(TFj|TFi,S)
        truthij = truth[:,i]*truth[:,j] # TFi && TFj
        if np.any(truthij):
            eq_aucs.append((np.count_nonzero(truthij), sklearn.metrics.roc_auc_score(truthij, our_pred), sklearn.metrics.roc_auc_score(truthij, deepsea_pred)))
            eq_prcs.append((np.count_nonzero(truthij), sklearn.metrics.average_precision_score(truthij, our_pred), sklearn.metrics.average_precision_score(truthij, deepsea_pred)))

        deepsea_pred = deepsea[:,i]*(1-deepsea[:,j]) #P(TFi|S)P(TFj|S)
        our_pred = deepsea[:,i]*(1-preds[:,j]) #P(TFi|S)P(TFj|TFi,S)
        truthij = truth[:,i]*(1-truth[:,j]) # TFi && TFj
        if np.any(truthij):
            j10_aucs.append((np.count_nonzero(truthij), sklearn.metrics.roc_auc_score(truthij, our_pred), sklearn.metrics.roc_auc_score(truthij, deepsea_pred)))
            j10_prcs.append((np.count_nonzero(truthij), sklearn.metrics.average_precision_score(truthij, our_pred), sklearn.metrics.average_precision_score(truthij, deepsea_pred)))

        deepsea_pred = deepsea[:,j] #P(TFj|S)
        our_pred = preds[:,j] #P(TFj|TFi,S)
        truthij = truth[:,j] # TFj
        if np.any(truthij):
            aucs.append((np.count_nonzero(truthij), sklearn.metrics.roc_auc_score(truthij, our_pred), sklearn.metrics.roc_auc_score(truthij, deepsea_pred)))
            prcs.append((np.count_nonzero(truthij), sklearn.metrics.average_precision_score(truthij, our_pred), sklearn.metrics.average_precision_score(truthij, deepsea_pred)))
            cond0_aucs.append((np.count_nonzero(truthij), sklearn.metrics.roc_auc_score(truthij, our_pred, sample_weight=1-truth[:,i]), sklearn.metrics.roc_auc_score(truthij, deepsea_pred, sample_weight=1-truth[:,i])))
            cond0_prcs.append((np.count_nonzero(truthij), sklearn.metrics.average_precision_score(truthij, our_pred, sample_weight=1-truth[:,i]), sklearn.metrics.average_precision_score(truthij, deepsea_pred, sample_weight=1-truth[:,i])))
            cond1_aucs.append((np.count_nonzero(truthij), sklearn.metrics.roc_auc_score(truthij, our_pred, sample_weight=truth[:,i]), sklearn.metrics.roc_auc_score(truthij, deepsea_pred, sample_weight=truth[:,i])))
            cond1_prcs.append((np.count_nonzero(truthij), sklearn.metrics.average_precision_score(truthij, our_pred, sample_weight=truth[:,i]), sklearn.metrics.average_precision_score(truthij, deepsea_pred, sample_weight=truth[:,i])))
    twoway_predsi = []
    for j in range(len(mlps)):
        if i == j:
            twoway_predsi.append([])
            continue
        our_pred = deepsea[:,i]*preds[:,j]
        deepsea_pred = deepsea[:,i]*deepsea[:,j]
        truthij = truth[:,i]*truth[:,j]
        if np.any(truthij):
            twoway_predsi.append((np.count_nonzero(truthij), our_pred, deepsea_pred, sklearn.metrics.roc_auc_score(truthij, our_pred), sklearn.metrics.roc_auc_score(truthij, deepsea_pred), (i,j)))
    twoway_preds.append(twoway_predsi)
# Out:
# INFO:tensorflow:Our AUC:     0.9602198199054667
# INFO:tensorflow:DeepSea AUC: 0.9582300797273284
# /data/jwhughes/miniconda3/envs/tf_env/lib/python3.6/site-packages/sklearn/metrics/ranking.py:443: RuntimeWarning: invalid value encountered in true_divide
#   precision = tps / (tps + fps)
# INFO:tensorflow:Our AUC:     0.953009997239823
# INFO:tensorflow:DeepSea AUC: 0.9561404407591383
# /data/jwhughes/miniconda3/envs/tf_env/lib/python3.6/site-packages/sklearn/metrics/ranking.py:571: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /data/jwhughes/miniconda3/envs/tf_env/lib/python3.6/site-packages/sklearn/metrics/ranking.py:444: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# INFO:tensorflow:Our AUC:     0.9583024728579127
# INFO:tensorflow:DeepSea AUC: 0.9590244014815782

# %%
# deepsea, preds, truth, _ = mlps[0].test(30000, log=True)
j = 1
# for j in range(18):
print(sklearn.metrics.average_precision_score(truth[:,j], preds[:,j]), sklearn.metrics.average_precision_score(truth[:,j], deepsea[:,j]))
# Out:
# 0.0203181217050717 0.056604253720988804

# %%
def plot(aucs, prcs=None, prob="", ranges=([.9,1],[.9,1])):
    cutoff = 0
    plt.scatter(x=[auc[2] for auc in aucs if auc[0] > cutoff],
                y=[auc[1] for auc in aucs if auc[0] > cutoff],
                s=100*np.array([auc[0] for auc in aucs if auc[0] > cutoff])/max([auc[0] for auc in aucs if auc[0] > cutoff]),
                c=np.array([[1,0,0]]*18+[[0,0,1]]*18+[[0,1,0]]*18))
    plt.plot([0, 1], [0, 1])
    plt.title("AUC on the binary classification problem " + prob)
    plt.xlabel("DeepSea AUC")
    plt.ylabel("Our AUC")
    plt.xlim(ranges[0])
    plt.ylim(ranges[1])
    print(len([auc[2] for auc in aucs if auc[0] > cutoff]))
    print(max([auc[0] for auc in aucs if auc[0] > cutoff]))
    plt.show()
    if prcs:
        cutoff = 0
        plt.scatter(x=[prc[2] for prc in prcs if prc[0] > cutoff],
                    y=[prc[1] for prc in prcs if prc[0] > cutoff],
                    s=100*np.array([prc[1] for prc in prcs if prc[0] > cutoff])/max([prc[1] for prc in prcs if prc[0] > cutoff]),
                    c=np.array([[1,0,0]]*18+[[0,0,1]]*18+[[0,1,0]]*18))
        plt.plot([0, 1], [0, 1])
        plt.title("AUPRC on the binary classification problem " + prob)
        plt.xlabel("DeepSea AUPRC")
        plt.ylabel("Our AUPRC")
        plt.show()
    
plot(eq_aucs, None, "$P(TF_i\cap TF_j | Seq)$")
plot(j10_aucs, None, "$P(TF_i\cap !TF_j | Seq)$", ([.8,1], [.2,1]))
plot(aucs, None, "$P(TF_j | TF_i, Seq)$")
# for i in range(3):
#     for j in range(i,3):
#         if i == j:
#             continue
# #         print(np.mean(abs(twoway_preds[i][j][1] - twoway_preds[j][i][1])))
#         assert np.all(twoway_preds[i][j][2] == twoway_preds[j][i][2])
#         print(i,j, twoway_preds[i][j][0])
#         print(np.mean(abs(twoway_preds[i][j][1] - twoway_preds[j][i][1])))
#         print(np.mean(abs(twoway_preds[i][j][1] - twoway_preds[i][j][2])))
#         print(np.mean(abs(twoway_preds[j][i][1] - twoway_preds[i][j][2])))
#     print()
# Out:
# 47
# 209
# 54
# 1264
# 54
# 1271

# %%
cutoff = 0
cond_aucs = cond1_aucs
plt.scatter(x=[auc[2] for auc in cond_aucs if auc[0] > cutoff],
            y=[auc[1] for auc in cond_aucs if auc[0] > cutoff],
            s=100*np.array([auc[0] for auc in cond_aucs if auc[0] > cutoff])/max([auc[0] for auc in cond_aucs if auc[0] > cutoff]),
            c=np.array([[1,0,0]]*18+[[0,0,1]]*18+[[0,1,0]]*18))
plt.plot([0, 1], [0, 1])
plt.title("AUC on the binary classification problem $P(TF_j | TF_i=1, Seq)$")
plt.xlabel("DeepSea AUC")
plt.ylabel("Our AUC")
plt.xlim([0.6,1])
plt.ylim([0.6,1])
print(len([auc[2] for auc in cond_aucs if auc[0] > cutoff]))
print(max([auc[0] for auc in cond_aucs if auc[0] > cutoff]))
plt.show()
cutoff = 0
plt.scatter(x=[prc[2] for prc in cond_prcs if prc[0] > cutoff],
            y=[prc[1] for prc in cond_prcs if prc[0] > cutoff],
            s=100*np.array([prc[1] for prc in cond_prcs if prc[0] > cutoff])/max([prc[1] for prc in cond_prcs if prc[0] > cutoff]),
            c=np.array([[1,0,0]]*18+[[0,0,1]]*18+[[0,1,0]]*18))
plt.plot([0, 1], [0, 1])
plt.title("AUPRC on the binary classification problem $P(TF_j | TF_i=1, Seq)$")
plt.xlabel("DeepSea AUPRC")
plt.ylabel("Our AUPRC");
# Out:
# 54
# 1271

# %%
cutoff = 0
cond_aucs = cond0_aucs
plt.scatter(x=[auc[2] for auc in cond_aucs if auc[0] > cutoff],
            y=[auc[1] for auc in cond_aucs if auc[0] > cutoff],
            s=100*np.array([auc[0] for auc in cond_aucs if auc[0] > cutoff])/max([auc[0] for auc in cond_aucs if auc[0] > cutoff]),
            c=np.array([[1,0,0]]*18+[[0,0,1]]*18+[[0,1,0]]*18))
plt.plot([0, 1], [0, 1])
plt.title("AUC on the binary classification problem $P(TF_j | TF_i=0, Seq)$")
plt.xlabel("DeepSea AUC")
plt.ylabel("Our AUC")
plt.xlim([0.85,1])
plt.ylim([0.85,1])
print(len([auc[2] for auc in cond_aucs if auc[0] > cutoff]))
print(max([auc[0] for auc in cond_aucs if auc[0] > cutoff]))
plt.show()
cutoff = 0
plt.scatter(x=[prc[2] for prc in cond_prcs if prc[0] > cutoff],
            y=[prc[1] for prc in cond_prcs if prc[0] > cutoff],
            s=100*np.array([prc[1] for prc in cond_prcs if prc[0] > cutoff])/max([prc[1] for prc in cond_prcs if prc[0] > cutoff]),
            c=np.array([[1,0,0]]*18+[[0,0,1]]*18+[[0,1,0]]*18))
plt.plot([0, 1], [0, 1])
plt.title("AUPRC on the binary classification problem $P(TF_j | TF_i=0, Seq)$")
plt.xlabel("DeepSea AUPRC")
plt.ylabel("Our AUPRC");
# Out:
# 54
# 1271

# %%
cutoff = 0
cond_aucs = cond01_aucs
plt.scatter(x=[auc[2] for auc in cond_aucs if auc[0] > cutoff],
            y=[auc[1] for auc in cond_aucs if auc[0] > cutoff],
            s=100*np.array([auc[0] for auc in cond_aucs if auc[0] > cutoff])/max([auc[0] for auc in cond_aucs if auc[0] > cutoff]),
            c=np.array([[1,0,0]]*18+[[0,0,1]]*18+[[0,1,0]]*18))
plt.plot([0, 1], [0, 1])
plt.title("AUC on the binary classification problem $P(TF_j | TF_i, Seq)$")
plt.xlabel("DeepSea AUC")
plt.ylabel("Our AUC")
plt.xlim([0.85,1])
plt.ylim([0.85,1])
print(len([auc[2] for auc in cond_aucs if auc[0] > cutoff]))
print(max([auc[0] for auc in cond_aucs if auc[0] > cutoff]))
plt.show()
cutoff = 0
plt.scatter(x=[prc[2] for prc in cond_prcs if prc[0] > cutoff],
            y=[prc[1] for prc in cond_prcs if prc[0] > cutoff],
            s=100*np.array([prc[1] for prc in cond_prcs if prc[0] > cutoff])/max([prc[1] for prc in cond_prcs if prc[0] > cutoff]),
            c=np.array([[1,0,0]]*18+[[0,0,1]]*18+[[0,1,0]]*18))
plt.plot([0, 1], [0, 1])
plt.title("AUPRC on the binary classification problem $P(TF_j | TF_i0, Seq)$")
plt.xlabel("DeepSea AUPRC")
plt.ylabel("Our AUPRC");
# Out:
# 54
# 1271

# %%
cond01_aucs = []
cond01_prcs = []
cond0_aucs = []
cond0_prcs = []
cond1_aucs = []
cond1_prcs = []
for i, mlp in enumerate(mlps):
    ds = mlp.make_alt_dataset(mlp, test_data, 64, 1, 10, paramaterized_imputation_gen(position_mask([i]), 3*19))
    deepsea, preds, truth, _ = mlp.test(30000, log=True, iterator_handle=ds)
    for j in range(19):
        if i == j: continue
        deepsea_pred = deepsea[:,j] #P(TFj|S)
        our_pred = preds[:,j] #P(TFj|TFi,S)
        truthij = truth[:,j] # TFj
        # (Set TFi below to 0 or 1)
        if np.any(truthij):
            cond01_aucs.append((np.count_nonzero(truthij), sklearn.metrics.roc_auc_score(truthij, our_pred), sklearn.metrics.roc_auc_score(truthij, deepsea_pred)))
            cond01_prcs.append((np.count_nonzero(truthij), sklearn.metrics.average_precision_score(truthij, our_pred), sklearn.metrics.average_precision_score(truthij, deepsea_pred)))
            cond0_aucs.append((np.count_nonzero(truthij), sklearn.metrics.roc_auc_score(truthij, our_pred, sample_weight=1-truth[:,i]), sklearn.metrics.roc_auc_score(truthij, deepsea_pred, sample_weight=1-truth[:,i])))
            cond0_prcs.append((np.count_nonzero(truthij), sklearn.metrics.average_precision_score(truthij, our_pred, sample_weight=1-truth[:,i]), sklearn.metrics.average_precision_score(truthij, deepsea_pred, sample_weight=1-truth[:,i])))
            cond1_aucs.append((np.count_nonzero(truthij), sklearn.metrics.roc_auc_score(truthij, our_pred, sample_weight=truth[:,i]), sklearn.metrics.roc_auc_score(truthij, deepsea_pred, sample_weight=truth[:,i])))
            cond1_prcs.append((np.count_nonzero(truthij), sklearn.metrics.average_precision_score(truthij, our_pred, sample_weight=truth[:,i]), sklearn.metrics.average_precision_score(truthij, deepsea_pred, sample_weight=truth[:,i])))
# Out:
# INFO:tensorflow:Our AUC:     0.958392464760152
# INFO:tensorflow:DeepSea AUC: 0.9582300797273284
# /data/jwhughes/miniconda3/envs/tf_env/lib/python3.6/site-packages/sklearn/metrics/ranking.py:443: RuntimeWarning: invalid value encountered in true_divide
#   precision = tps / (tps + fps)
# INFO:tensorflow:Our AUC:     0.9522257134387123
# INFO:tensorflow:DeepSea AUC: 0.9561404407591383
# /data/jwhughes/miniconda3/envs/tf_env/lib/python3.6/site-packages/sklearn/metrics/ranking.py:571: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /data/jwhughes/miniconda3/envs/tf_env/lib/python3.6/site-packages/sklearn/metrics/ranking.py:444: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# INFO:tensorflow:Our AUC:     0.9576052687925529
# INFO:tensorflow:DeepSea AUC: 0.9590244014815782
